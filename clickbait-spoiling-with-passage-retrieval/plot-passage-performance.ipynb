# %% [markdown]
# # Plot Passage Performance

# %%
import pandas as pd
import json
from glob import glob

DIR = './'

approaches = ['passage-retrieval-t5', 'passage-retrieval-bert', 'sentence-retrieval-t5', 'sentence-retrieval-bert'] + glob('sentence-retrieval-bm25/*/') + glob('passage-retrieval-bm25/*/') + glob('sentence-retrieval-qld/*/') + glob('passage-retrieval-qld/*/')
df = []

thresholds = {
    'phrase': {
        'bertscore_score': 0.3,
        'meteor_score': 0.1,
        'bleu4_score': 0.1,
    }, 'passage': {
        'bertscore_score': 0.5,
        'meteor_score': 0.3,
        'bleu4_score': 0.05,
    }
}

for approach in approaches:
    for t in ['phrase', 'passage']:
        i = json.load(open(DIR + approach + '/eval-' + t + '/all_scores.json'))
        
        correctBleu = 0;
        correctBertScore = 0;
        correctMeteor = 0;
        
        for k in i['single_scores'].keys():
            tmp = i['single_scores'][k]
            if tmp['bertscore_score'] >= thresholds[t]['bertscore_score']:
                correctBertScore += 1
                
            if tmp['meteor_score'] >= thresholds[t]['meteor_score']:
                correctMeteor += 1
                
            if tmp['bleu4_score'] >= thresholds[t]['bleu4_score']:
                correctBleu += 1
               
        df += [{
            'Retrieval Model': approach.split('-retrieval-')[1],
            'Retrieval Unit': approach.split('-retrieval-')[0],
            'Type of Clickbait': t,
            'Bleu': i['scores']['bleu4_lemma'],
            'Meteor': i['scores']['meteor_score'],
            'BertScore': i['scores']['bertscore_score'],
            'correctBleu': correctBleu,
            'correctMeteor': correctMeteor,
            'correctBertScore': correctBertScore,
        }]

df = pd.DataFrame(df)
df.sort_values('Meteor', ascending=False)
# Out:
#        Retrieval Model Retrieval Unit Type of Clickbait      Bleu    Meteor  \
# 7                 bert       sentence           passage  0.104317  0.223731
# 5                   t5       sentence           passage  0.105794  0.220221
# 11  bm25/k1=0.8-b=0.4/       sentence           passage  0.079079  0.201949
# 21  bm25/k1=1.0-b=0.4/       sentence           passage  0.076110  0.199053
# 19  bm25/k1=0.9-b=0.3/       sentence           passage  0.076099  0.198704
# ..                 ...            ...               ...       ...       ...
# 68      qld/mu=1150.0/        passage            phrase  0.030630  0.035003
# 34  bm25/k1=1.0-b=0.3/        passage            phrase  0.029809  0.034986
# 78      qld/mu=1200.0/        passage            phrase  0.030630  0.034970
# 42  bm25/k1=0.8-b=0.3/        passage            phrase  0.029870  0.034962
# 36  bm25/k1=0.9-b=0.3/        passage            phrase  0.029870  0.034959
#
#     BertScore  correctBleu  correctMeteor  correctBertScore
# 7    0.365839           74             75                46
# 5    0.367044           74             74                46
# 11   0.347100           53             61                42
# 21   0.345570           51             59                41
# 19   0.346124           51             59                41
# ..        ...          ...            ...               ...
# 68   0.191875           39             68                 8
# 34   0.191816           35             66                 7
# 78   0.191685           39             68                 8
# 42   0.191832           35             66                 7
# 36   0.191849           35             66                 7
#
# [80 rows x 9 columns]

# %%
df[df['Type of Clickbait'] == 'phrase'].sort_values('Meteor', ascending=False)
# Out:
#        Retrieval Model Retrieval Unit Type of Clickbait      Bleu    Meteor  \
# 4                   t5       sentence            phrase  0.049520  0.064755
# 6                 bert       sentence            phrase  0.042093  0.061090
# 8   bm25/k1=1.0-b=0.5/       sentence            phrase  0.034047  0.050623
# 12  bm25/k1=0.9-b=0.5/       sentence            phrase  0.034047  0.050531
# 22  bm25/k1=0.8-b=0.5/       sentence            phrase  0.033126  0.050003
# 14  bm25/k1=0.9-b=0.4/       sentence            phrase  0.033160  0.049323
# 20  bm25/k1=1.0-b=0.4/       sentence            phrase  0.033023  0.049176
# 10  bm25/k1=0.8-b=0.4/       sentence            phrase  0.033047  0.049108
# 16  bm25/k1=1.0-b=0.3/       sentence            phrase  0.032630  0.048526
# 18  bm25/k1=0.9-b=0.3/       sentence            phrase  0.032630  0.048526
# 24  bm25/k1=0.8-b=0.3/       sentence            phrase  0.032649  0.048365
# 56      qld/mu=1000.0/       sentence            phrase  0.033353  0.048227
# 48       qld/mu=850.0/       sentence            phrase  0.033353  0.048227
# 50      qld/mu=1150.0/       sentence            phrase  0.033353  0.048227
# 52       qld/mu=950.0/       sentence            phrase  0.033353  0.048227
# 54      qld/mu=1100.0/       sentence            phrase  0.033353  0.048227
# 44       qld/mu=800.0/       sentence            phrase  0.033353  0.048227
# 58      qld/mu=1050.0/       sentence            phrase  0.033353  0.048227
# 60      qld/mu=1200.0/       sentence            phrase  0.033353  0.048227
# 46       qld/mu=900.0/       sentence            phrase  0.033353  0.048227
# 0                   t5        passage            phrase  0.037762  0.042902
# 2                 bert        passage            phrase  0.034637  0.041097
# 26  bm25/k1=1.0-b=0.5/        passage            phrase  0.030446  0.035521
# 40  bm25/k1=0.8-b=0.5/        passage            phrase  0.030364  0.035318
# 38  bm25/k1=1.0-b=0.4/        passage            phrase  0.030158  0.035308
# 30  bm25/k1=0.9-b=0.5/        passage            phrase  0.030260  0.035277
# 32  bm25/k1=0.9-b=0.4/        passage            phrase  0.030076  0.035227
# 28  bm25/k1=0.8-b=0.4/        passage            phrase  0.030029  0.035225
# 62       qld/mu=800.0/        passage            phrase  0.030684  0.035080
# 64       qld/mu=900.0/        passage            phrase  0.030684  0.035080
# 66       qld/mu=850.0/        passage            phrase  0.030684  0.035080
# 70       qld/mu=950.0/        passage            phrase  0.030684  0.035080
# 72      qld/mu=1100.0/        passage            phrase  0.030684  0.035080
# 74      qld/mu=1000.0/        passage            phrase  0.030684  0.035080
# 76      qld/mu=1050.0/        passage            phrase  0.030684  0.035080
# 68      qld/mu=1150.0/        passage            phrase  0.030630  0.035003
# 34  bm25/k1=1.0-b=0.3/        passage            phrase  0.029809  0.034986
# 78      qld/mu=1200.0/        passage            phrase  0.030630  0.034970
# 42  bm25/k1=0.8-b=0.3/        passage            phrase  0.029870  0.034962
# 36  bm25/k1=0.9-b=0.3/        passage            phrase  0.029870  0.034959
#
#     BertScore  correctBleu  correctMeteor  correctBertScore
# 4    0.209806           82            115                16
# 6    0.206653           72            103                11
# 8    0.199421           55             83                12
# 12   0.199440           55             83                12
# 22   0.198728           54             82                11
# 14   0.198778           54             82                11
# 20   0.198576           54             82                11
# 10   0.198524           54             81                11
# 16   0.198145           53             80                11
# 18   0.198147           53             80                11
# 24   0.198075           53             80                11
# 56   0.198343           53             82                13
# 48   0.198344           53             82                13
# 50   0.198343           53             82                13
# 52   0.198344           53             82                13
# 54   0.198343           53             82                13
# 44   0.198343           53             82                13
# 58   0.198344           53             82                13
# 60   0.198343           53             82                13
# 46   0.198343           53             82                13
# 0    0.198972           43             85                 9
# 2    0.196153           37             80                 8
# 26   0.192788           38             68                 7
# 40   0.192143           37             68                 7
# 38   0.191998           36             67                 7
# 30   0.192316           37             68                 7
# 32   0.191942           36             67                 7
# 28   0.191923           36             67                 7
# 62   0.191932           39             68                 8
# 64   0.191934           39             68                 8
# 66   0.191933           39             68                 8
# 70   0.191931           39             68                 8
# 72   0.191932           39             68                 8
# 74   0.191933           39             68                 8
# 76   0.191929           39             68                 8
# 68   0.191875           39             68                 8
# 34   0.191816           35             66                 7
# 78   0.191685           39             68                 8
# 42   0.191832           35             66                 7
# 36   0.191849           35             66                 7

# %%
df[df['Type of Clickbait'] == 'phrase'].sort_values('Meteor', ascending=False)
# Out:
#        Retrieval Model Retrieval Unit Type of Clickbait      Bleu    Meteor  \
# 4                   t5       sentence            phrase  0.049520  0.064755
# 6                 bert       sentence            phrase  0.042093  0.061090
# 8   bm25/k1=1.0-b=0.5/       sentence            phrase  0.034047  0.050623
# 12  bm25/k1=0.9-b=0.5/       sentence            phrase  0.034047  0.050531
# 22  bm25/k1=0.8-b=0.5/       sentence            phrase  0.033126  0.050003
# 14  bm25/k1=0.9-b=0.4/       sentence            phrase  0.033160  0.049323
# 20  bm25/k1=1.0-b=0.4/       sentence            phrase  0.033023  0.049176
# 10  bm25/k1=0.8-b=0.4/       sentence            phrase  0.033047  0.049108
# 16  bm25/k1=1.0-b=0.3/       sentence            phrase  0.032630  0.048526
# 18  bm25/k1=0.9-b=0.3/       sentence            phrase  0.032630  0.048526
# 24  bm25/k1=0.8-b=0.3/       sentence            phrase  0.032649  0.048365
# 56      qld/mu=1000.0/       sentence            phrase  0.033353  0.048227
# 48       qld/mu=850.0/       sentence            phrase  0.033353  0.048227
# 50      qld/mu=1150.0/       sentence            phrase  0.033353  0.048227
# 52       qld/mu=950.0/       sentence            phrase  0.033353  0.048227
# 54      qld/mu=1100.0/       sentence            phrase  0.033353  0.048227
# 44       qld/mu=800.0/       sentence            phrase  0.033353  0.048227
# 58      qld/mu=1050.0/       sentence            phrase  0.033353  0.048227
# 60      qld/mu=1200.0/       sentence            phrase  0.033353  0.048227
# 46       qld/mu=900.0/       sentence            phrase  0.033353  0.048227
# 0                   t5        passage            phrase  0.037762  0.042902
# 2                 bert        passage            phrase  0.034637  0.041097
# 26  bm25/k1=1.0-b=0.5/        passage            phrase  0.030446  0.035521
# 40  bm25/k1=0.8-b=0.5/        passage            phrase  0.030364  0.035318
# 38  bm25/k1=1.0-b=0.4/        passage            phrase  0.030158  0.035308
# 30  bm25/k1=0.9-b=0.5/        passage            phrase  0.030260  0.035277
# 32  bm25/k1=0.9-b=0.4/        passage            phrase  0.030076  0.035227
# 28  bm25/k1=0.8-b=0.4/        passage            phrase  0.030029  0.035225
# 62       qld/mu=800.0/        passage            phrase  0.030684  0.035080
# 64       qld/mu=900.0/        passage            phrase  0.030684  0.035080
# 66       qld/mu=850.0/        passage            phrase  0.030684  0.035080
# 70       qld/mu=950.0/        passage            phrase  0.030684  0.035080
# 72      qld/mu=1100.0/        passage            phrase  0.030684  0.035080
# 74      qld/mu=1000.0/        passage            phrase  0.030684  0.035080
# 76      qld/mu=1050.0/        passage            phrase  0.030684  0.035080
# 68      qld/mu=1150.0/        passage            phrase  0.030630  0.035003
# 34  bm25/k1=1.0-b=0.3/        passage            phrase  0.029809  0.034986
# 78      qld/mu=1200.0/        passage            phrase  0.030630  0.034970
# 42  bm25/k1=0.8-b=0.3/        passage            phrase  0.029870  0.034962
# 36  bm25/k1=0.9-b=0.3/        passage            phrase  0.029870  0.034959
#
#     BertScore  correctBleu  correctMeteor  correctBertScore
# 4    0.209806           82            115                16
# 6    0.206653           72            103                11
# 8    0.199421           55             83                12
# 12   0.199440           55             83                12
# 22   0.198728           54             82                11
# 14   0.198778           54             82                11
# 20   0.198576           54             82                11
# 10   0.198524           54             81                11
# 16   0.198145           53             80                11
# 18   0.198147           53             80                11
# 24   0.198075           53             80                11
# 56   0.198343           53             82                13
# 48   0.198344           53             82                13
# 50   0.198343           53             82                13
# 52   0.198344           53             82                13
# 54   0.198343           53             82                13
# 44   0.198343           53             82                13
# 58   0.198344           53             82                13
# 60   0.198343           53             82                13
# 46   0.198343           53             82                13
# 0    0.198972           43             85                 9
# 2    0.196153           37             80                 8
# 26   0.192788           38             68                 7
# 40   0.192143           37             68                 7
# 38   0.191998           36             67                 7
# 30   0.192316           37             68                 7
# 32   0.191942           36             67                 7
# 28   0.191923           36             67                 7
# 62   0.191932           39             68                 8
# 64   0.191934           39             68                 8
# 66   0.191933           39             68                 8
# 70   0.191931           39             68                 8
# 72   0.191932           39             68                 8
# 74   0.191933           39             68                 8
# 76   0.191929           39             68                 8
# 68   0.191875           39             68                 8
# 34   0.191816           35             66                 7
# 78   0.191685           39             68                 8
# 42   0.191832           35             66                 7
# 36   0.191849           35             66                 7

# %%
from glob import glob
glob('sentence-retrieval-qld/*/')
# Out:
# ['sentence-retrieval-qld/mu=800.0/',
#  'sentence-retrieval-qld/mu=900.0/',
#  'sentence-retrieval-qld/mu=850.0/',
#  'sentence-retrieval-qld/mu=1150.0/',
#  'sentence-retrieval-qld/mu=950.0/',
#  'sentence-retrieval-qld/mu=1100.0/',
#  'sentence-retrieval-qld/mu=1000.0/',
#  'sentence-retrieval-qld/mu=1050.0/',
#  'sentence-retrieval-qld/mu=1200.0/']

# %% [markdown]
# # Plot Performance Pilot Experiments

# %%
import pandas as pd
import json

DIR = './test-200/'

approaches = ['sentence-retrieval-bert', 'sentence-retrieval-t5', 'sentence-retrieval-bm25',
              'sentence-retrieval-bm25-rm3', 'sentence-retrieval-bm25-ax', 'sentence-retrieval-bm25-prf',
              'sentence-retrieval-qld',
              'sentence-retrieval-qld+rm3', 'sentence-retrieval-ax', 'sentence-retrieval-prf']
df = []

#thresholds = {
#    'phrase': {
#        'bertscore_score': 0.8,
#        'meteor_score': 0.7,
#        'bleu4_score': 0.5,
#    }, 'passage': {
#        'bertscore_score': 0.6,
#        'meteor_score': 0.7,
#        'bleu4_score': 0.3,
#    }
#}

thresholds = {
    'phrase': {
        'bertscore_score': 0.3,
        'meteor_score': 0.1,
        'bleu4_score': 0.1,
    }, 'passage': {
        'bertscore_score': 0.5,
        'meteor_score': 0.3,
        'bleu4_score': 0.05,
    }
}

for approach in approaches:
    for t in ['phrase', 'passage']:
        i = json.load(open(DIR + approach + '/eval-' + t + '/all_scores.json'))
        
        correctBleu = 0;
        correctBertScore = 0;
        correctMeteor = 0;
        
        for k in i['single_scores'].keys():
            tmp = i['single_scores'][k]
            if tmp['bertscore_score'] >= thresholds[t]['bertscore_score']:
                correctBertScore += 1
                
            if tmp['meteor_score'] >= thresholds[t]['meteor_score']:
                correctMeteor += 1
                
            if tmp['bleu4_score'] >= thresholds[t]['bleu4_score']:
                correctBleu += 1
               
        df += [{
            'Retrieval Model': approach.split('-retrieval-')[1],
            'Retrieval Unit': approach.split('-retrieval-')[0],
            'Type of Clickbait': t,
            'Bleu': i['scores']['bleu4_lemma'],
            'Meteor': i['scores']['meteor_score'],
            'BertScore': i['scores']['bertscore_score'],
            'correctBleu': correctBleu,
            'correctMeteor': correctMeteor,
            'correctBertScore': correctBertScore,
        }]

df = pd.DataFrame(df)
df.sort_values('Meteor', ascending=False)
# Out:
#    Retrieval Model Retrieval Unit Type of Clickbait      Bleu    Meteor  \
# 1             bert       sentence           passage  0.145508  0.268646
# 3               t5       sentence           passage  0.142781  0.267001
# 5             bm25       sentence           passage  0.114937  0.226425
# 9          bm25-ax       sentence           passage  0.112710  0.224623
# 11        bm25-prf       sentence           passage  0.096853  0.211020
# 7         bm25-rm3       sentence           passage  0.100687  0.210335
# 17              ax       sentence           passage  0.106843  0.188479
# 15         qld+rm3       sentence           passage  0.116689  0.185470
# 13             qld       sentence           passage  0.109475  0.178064
# 19             prf       sentence           passage  0.108628  0.175287
# 2               t5       sentence            phrase  0.031680  0.041892
# 0             bert       sentence            phrase  0.034261  0.041312
# 10        bm25-prf       sentence            phrase  0.032584  0.038172
# 4             bm25       sentence            phrase  0.034883  0.036743
# 6         bm25-rm3       sentence            phrase  0.034307  0.036206
# 8          bm25-ax       sentence            phrase  0.033942  0.035717
# 16              ax       sentence            phrase  0.026183  0.027130
# 18             prf       sentence            phrase  0.026007  0.027011
# 12             qld       sentence            phrase  0.025135  0.026965
# 14         qld+rm3       sentence            phrase  0.024119  0.025414
#
#     BertScore  correctBleu  correctMeteor  correctBertScore
# 1    0.381046           29             25                15
# 3    0.389429           29             26                17
# 5    0.367956           22             21                12
# 9    0.365187           21             19                12
# 11   0.354476           18             16                11
# 7    0.355587           19             17                12
# 17   0.366859           24             17                11
# 15   0.371335           27             19                12
# 13   0.366973           25             18                11
# 19   0.364695           23             17                11
# 2    0.182969            9             11                 0
# 0    0.183270           11             12                 1
# 10   0.180344           10             10                 2
# 4    0.177391           10              9                 0
# 6    0.181415           10             10                 2
# 8    0.180745           10             10                 2
# 16   0.171030            7              7                 0
# 18   0.171356            7              7                 0
# 12   0.172471            7              7                 0
# 14   0.169797            7              7                 0

# %%
df[df['Type of Clickbait'] == 'passage'].sort_values('Meteor', ascending=False)
# Out:
#    Retrieval Model Retrieval Unit Type of Clickbait      Bleu    Meteor  \
# 1             bert       sentence           passage  0.145508  0.268646
# 3               t5       sentence           passage  0.142781  0.267001
# 5             bm25       sentence           passage  0.114937  0.226425
# 9          bm25-ax       sentence           passage  0.112710  0.224623
# 11        bm25-prf       sentence           passage  0.096853  0.211020
# 7         bm25-rm3       sentence           passage  0.100687  0.210335
# 17              ax       sentence           passage  0.106843  0.188479
# 15         qld+rm3       sentence           passage  0.116689  0.185470
# 13             qld       sentence           passage  0.109475  0.178064
# 19             prf       sentence           passage  0.108628  0.175287
#
#     BertScore  correctBleu  correctMeteor  correctBertScore
# 1    0.381046           29             25                15
# 3    0.389429           29             26                17
# 5    0.367956           22             21                12
# 9    0.365187           21             19                12
# 11   0.354476           18             16                11
# 7    0.355587           19             17                12
# 17   0.366859           24             17                11
# 15   0.371335           27             19                12
# 13   0.366973           25             18                11
# 19   0.364695           23             17                11

# %%
import pandas as pd
import json

DIR = './end-to-end-evaluation/'

approaches = ['bert-with-roberta-predictor', 'roberta-with-roberta-predictor', 'debert-with-roberta-predictor']
df = []

thresholds = {
    'phrase': {
        'bertscore_score': 0.8,
        'meteor_score': 0.7,
        'bleu4_score': 0.5,
    }, 'passage': {
        'bertscore_score': 0.6,
        'meteor_score': 0.7,
        'bleu4_score': 0.3,
    }
}

for approach in approaches:
    for t in ['phrase', 'passage']:
        i = json.load(open(DIR + approach + '/eval-' + t + '/all_scores.json'))
        
        correctBleu = 0;
        correctBertScore = 0;
        correctMeteor = 0;
        
        for k in i['single_scores'].keys():
            tmp = i['single_scores'][k]
            if tmp['bertscore_score'] >= thresholds[t]['bertscore_score']:
                correctBertScore += 1
                
            if tmp['meteor_score'] >= thresholds[t]['meteor_score']:
                correctMeteor += 1
                
            if tmp['bleu4_score'] >= thresholds[t]['bleu4_score']:
                correctBleu += 1
               
        df += [{
            'Retrieval Model': approach,
            'Retrieval Unit': approach.split('-retrieval-')[0],
            'Type of Clickbait': t,
            'Bleu': i['scores']['bleu4_lemma'],
            'Meteor': i['scores']['meteor_score'],
            'BertScore': i['scores']['bertscore_score'],
            'correctBleu': correctBleu,
            'correctMeteor': correctMeteor,
            'correctBertScore': correctBertScore,
        }]

df = pd.DataFrame(df)
df.sort_values('Meteor', ascending=False)
# Out:
#                   Retrieval Model                  Retrieval Unit  \
# 5   debert-with-roberta-predictor   debert-with-roberta-predictor
# 2  roberta-with-roberta-predictor  roberta-with-roberta-predictor
# 3  roberta-with-roberta-predictor  roberta-with-roberta-predictor
# 4   debert-with-roberta-predictor   debert-with-roberta-predictor
# 0     bert-with-roberta-predictor     bert-with-roberta-predictor
# 1     bert-with-roberta-predictor     bert-with-roberta-predictor
#
#   Type of Clickbait      Bleu    Meteor  BertScore  correctBleu  \
# 5           passage  0.282032  0.450424   0.482231          143
# 2            phrase  0.587995  0.434071   0.688078          247
# 3           passage  0.258028  0.432196   0.466824          127
# 4            phrase  0.609705  0.421388   0.696292          249
# 0            phrase  0.529633  0.364308   0.657784          222
# 1           passage  0.180952  0.335924   0.413483           89
#
#    correctMeteor  correctBertScore
# 5            133               156
# 2            229               205
# 3            127               156
# 4            244               222
# 0            218               195
# 1             85                99

# %%
df.sort_values('Retrieval Model', ascending=False)
# Out:
#                   Retrieval Model                  Retrieval Unit  \
# 2  roberta-with-roberta-predictor  roberta-with-roberta-predictor
# 3  roberta-with-roberta-predictor  roberta-with-roberta-predictor
# 4   debert-with-roberta-predictor   debert-with-roberta-predictor
# 5   debert-with-roberta-predictor   debert-with-roberta-predictor
# 0     bert-with-roberta-predictor     bert-with-roberta-predictor
# 1     bert-with-roberta-predictor     bert-with-roberta-predictor
#
#   Type of Clickbait      Bleu    Meteor  BertScore  correctBleu  \
# 2            phrase  0.587995  0.434071   0.688078          247
# 3           passage  0.258028  0.432196   0.466824          127
# 4            phrase  0.609705  0.421388   0.696292          249
# 5           passage  0.282032  0.450424   0.482231          143
# 0            phrase  0.529633  0.364308   0.657784          222
# 1           passage  0.180952  0.335924   0.413483           89
#
#    correctMeteor  correctBertScore
# 2            229               205
# 3            127               156
# 4            244               222
# 5            133               156
# 0            218               195
# 1             85                99
